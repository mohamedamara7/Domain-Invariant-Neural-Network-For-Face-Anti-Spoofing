# %%
import tensorflow as tf
# Out:
# WARNING: Logging before InitGoogle() is written to STDERR
# E0000 00:00:1719797087.167917    6030 common_lib.cc:798] Could not set metric server port: INVALID_ARGUMENT: Could not find SliceBuilder port 8471 in any of the 0 ports provided in `tpu_process_addresses`="localhost"
# === Source Location Trace: ===
# learning/45eac/tfrc/runtime/common_lib.cc:479
# D0701 01:24:47.218039756    6030 config.cc:196]                        gRPC EXPERIMENT call_status_override_on_cancellation   OFF (default:OFF)
# D0701 01:24:47.218063011    6030 config.cc:196]                        gRPC EXPERIMENT call_v3                                OFF (default:OFF)
# D0701 01:24:47.218066752    6030 config.cc:196]                        gRPC EXPERIMENT canary_client_privacy                  ON  (default:ON)
# D0701 01:24:47.218069334    6030 config.cc:196]                        gRPC EXPERIMENT capture_base_context                   ON  (default:ON)
# D0701 01:24:47.218071819    6030 config.cc:196]                        gRPC EXPERIMENT client_idleness                        ON  (default:ON)
# D0701 01:24:47.218074240    6030 config.cc:196]                        gRPC EXPERIMENT client_privacy                         ON  (default:ON)
# D0701 01:24:47.218076679    6030 config.cc:196]                        gRPC EXPERIMENT dapper_request_wire_size               OFF (default:OFF)
# D0701 01:24:47.218079012    6030 config.cc:196]                        gRPC EXPERIMENT empty_experiment                       OFF (default:OFF)
# D0701 01:24:47.218081330    6030 config.cc:196]                        gRPC EXPERIMENT event_engine_client                    OFF (default:OFF)
# D0701 01:24:47.218083628    6030 config.cc:196]                        gRPC EXPERIMENT event_engine_dns                       ON  (default:ON)
# D0701 01:24:47.218085938    6030 config.cc:196]                        gRPC EXPERIMENT event_engine_listener                  ON  (default:ON)
# D0701 01:24:47.218088315    6030 config.cc:196]                        gRPC EXPERIMENT free_large_allocator                   OFF (default:OFF)
# D0701 01:24:47.218090663    6030 config.cc:196]                        gRPC EXPERIMENT google_no_envelope_resolver            OFF (default:OFF)
# D0701 01:24:47.218092999    6030 config.cc:196]                        gRPC EXPERIMENT http2_stats_fix                        OFF (default:OFF)
# D0701 01:24:47.218095283    6030 config.cc:196]                        gRPC EXPERIMENT keepalive_fix                          OFF (default:OFF)
# D0701 01:24:47.218097613    6030 config.cc:196]                        gRPC EXPERIMENT keepalive_server_fix                   ON  (default:ON)
# D0701 01:24:47.218100071    6030 config.cc:196]                        gRPC EXPERIMENT loas_do_not_prefer_rekey_next_protocol OFF (default:OFF)
# D0701 01:24:47.218102451    6030 config.cc:196]                        gRPC EXPERIMENT loas_prod_to_cloud_prefer_pfs_ciphers  OFF (default:OFF)
# D0701 01:24:47.218104787    6030 config.cc:196]                        gRPC EXPERIMENT monitoring_experiment                  ON  (default:ON)
# D0701 01:24:47.218107123    6030 config.cc:196]                        gRPC EXPERIMENT multiping                              OFF (default:OFF)
# D0701 01:24:47.218109437    6030 config.cc:196]                        gRPC EXPERIMENT peer_state_based_framing               OFF (default:OFF)
# D0701 01:24:47.218111779    6030 config.cc:196]                        gRPC EXPERIMENT pending_queue_cap                      ON  (default:ON)
# D0701 01:24:47.218114186    6030 config.cc:196]                        gRPC EXPERIMENT pick_first_happy_eyeballs              ON  (default:ON)
# D0701 01:24:47.218116534    6030 config.cc:196]                        gRPC EXPERIMENT promise_based_client_call              OFF (default:OFF)
# D0701 01:24:47.218118787    6030 config.cc:196]                        gRPC EXPERIMENT promise_based_inproc_transport         OFF (default:OFF)
# D0701 01:24:47.218121031    6030 config.cc:196]                        gRPC EXPERIMENT promise_based_server_call              OFF (default:OFF)
# D0701 01:24:47.218123417    6030 config.cc:196]                        gRPC EXPERIMENT registered_method_lookup_in_transport  ON  (default:ON)
# D0701 01:24:47.218125761    6030 config.cc:196]                        gRPC EXPERIMENT rfc_max_concurrent_streams             ON  (default:ON)
# D0701 01:24:47.218128159    6030 config.cc:196]                        gRPC EXPERIMENT round_robin_delegate_to_pick_first     ON  (default:ON)
# D0701 01:24:47.218132255    6030 config.cc:196]                        gRPC EXPERIMENT rstpit                                 OFF (default:OFF)
# D0701 01:24:47.218134691    6030 config.cc:196]                        gRPC EXPERIMENT schedule_cancellation_over_write       OFF (default:OFF)
# D0701 01:24:47.218137487    6030 config.cc:196]                        gRPC EXPERIMENT server_privacy                         ON  (default:ON)
# D0701 01:24:47.218140019    6030 config.cc:196]                        gRPC EXPERIMENT tcp_frame_size_tuning                  OFF (default:OFF)
# D0701 01:24:47.218142382    6030 config.cc:196]                        gRPC EXPERIMENT tcp_rcv_lowat                          OFF (default:OFF)
# D0701 01:24:47.218144707    6030 config.cc:196]                        gRPC EXPERIMENT trace_record_callops                   OFF (default:OFF)
# D0701 01:24:47.218147010    6030 config.cc:196]                        gRPC EXPERIMENT unconstrained_max_quota_buffer_size    OFF (default:OFF)
# D0701 01:24:47.218149248    6030 config.cc:196]                        gRPC EXPERIMENT v3_backend_metric_filter               OFF (default:OFF)
# D0701 01:24:47.218151560    6030 config.cc:196]                        gRPC EXPERIMENT v3_channel_idle_filters                ON  (default:ON)
# D0701 01:24:47.218153931    6030 config.cc:196]                        gRPC EXPERIMENT v3_compression_filter                  ON  (default:ON)
# D0701 01:24:47.218156231    6030 config.cc:196]                        gRPC EXPERIMENT v3_server_auth_filter                  OFF (default:OFF)
# D0701 01:24:47.218158518    6030 config.cc:196]                        gRPC EXPERIMENT work_serializer_clears_time_cache      OFF (default:OFF)
# D0701 01:24:47.218160781    6030 config.cc:196]                        gRPC EXPERIMENT work_serializer_dispatch               OFF (default:OFF)
# D0701 01:24:47.218163107    6030 config.cc:196]                        gRPC EXPERIMENT write_size_cap                         ON  (default:ON)
# D0701 01:24:47.218165472    6030 config.cc:196]                        gRPC EXPERIMENT write_size_policy                      ON  (default:ON)
# D0701 01:24:47.218167837    6030 config.cc:196]                        gRPC EXPERIMENT wrr_delegate_to_pick_first             ON  (default:ON)
# I0701 01:24:47.222305541    6030 ev_epoll1_linux.cc:123]               grpc epoll fd: 58
# D0701 01:24:47.222326235    6030 ev_posix.cc:113]                      Using polling engine: epoll1
# D0701 01:24:47.247420660    6030 lb_policy_registry.cc:46]             registering LB policy factory for "priority_experimental"
# D0701 01:24:47.247444070    6030 lb_policy_registry.cc:46]             registering LB policy factory for "outlier_detection_experimental"
# D0701 01:24:47.248211493    6030 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_target_experimental"
# D0701 01:24:47.248217220    6030 lb_policy_registry.cc:46]             registering LB policy factory for "pick_first"
# D0701 01:24:47.248227994    6030 lb_policy_registry.cc:46]             registering LB policy factory for "round_robin"
# D0701 01:24:47.248231309    6030 lb_policy_registry.cc:46]             registering LB policy factory for "weighted_round_robin"
# D0701 01:24:47.250808657    6030 lb_policy_registry.cc:46]             registering LB policy factory for "grpclb"
# D0701 01:24:47.250888445    6030 dns_resolver_plugin.cc:43]            Using EventEngine dns resolver
# D0701 01:24:47.251998518    6030 lb_policy_registry.cc:46]             registering LB policy factory for "rls_experimental"
# D0701 01:24:47.253036900    6030 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_manager_experimental"
# D0701 01:24:47.253927541    6030 lb_policy_registry.cc:46]             registering LB policy factory for "xds_cluster_impl_experimental"
# D0701 01:24:47.253933567    6030 lb_policy_registry.cc:46]             registering LB policy factory for "cds_experimental"
# D0701 01:24:47.253938565    6030 lb_policy_registry.cc:46]             registering LB policy factory for "xds_override_host_experimental"
# D0701 01:24:47.253949529    6030 lb_policy_registry.cc:46]             registering LB policy factory for "xds_wrr_locality_experimental"
# D0701 01:24:47.253960206    6030 lb_policy_registry.cc:46]             registering LB policy factory for "ring_hash_experimental"
# D0701 01:24:47.253964266    6030 certificate_provider_registry.cc:33]  registering certificate provider factory for "file_watcher"
# D0701 01:24:47.254006903    6030 channel_init.cc:157]                  Filter server-auth not registered, but is referenced in the after clause of grpc-server-authz when building channel stack SERVER_CHANNEL
# I0701 01:24:47.256581935    6030 ev_epoll1_linux.cc:359]               grpc epoll fd: 60
# I0701 01:24:47.265550205    6030 tcp_socket_utils.cc:689]              Disabling AF_INET6 sockets because ::1 is not available.
# I0701 01:24:47.342772107    6119 socket_utils_common_posix.cc:452]     Disabling AF_INET6 sockets because ::1 is not available.
# I0701 01:24:47.342833894    6119 socket_utils_common_posix.cc:379]     TCP_USER_TIMEOUT is available. TCP_USER_TIMEOUT will be used thereafter
# E0701 01:24:47.352172684    6115 oauth2_credentials.cc:238]            oauth_fetch: UNKNOWN:C-ares status is not ARES_SUCCESS qtype=A name=metadata.google.internal. is_balancer=0: Domain name not found {created_time:"2024-07-01T01:24:47.352154646+00:00", grpc_status:2}

# %%
tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
tf.config.experimental_connect_to_cluster(tpu)
tf.tpu.experimental.initialize_tpu_system(tpu)
strategy = tf.distribute.TPUStrategy(tpu)
# Out:
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1719797097.509275    6030 service.cc:145] XLA service 0x5d386e356c20 initialized for platform TPU (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1719797097.509356    6030 service.cc:153]   StreamExecutor device (0): TPU, 2a886c8
# I0000 00:00:1719797097.509361    6030 service.cc:153]   StreamExecutor device (1): TPU, 2a886c8
# I0000 00:00:1719797097.509364    6030 service.cc:153]   StreamExecutor device (2): TPU, 2a886c8
# I0000 00:00:1719797097.509367    6030 service.cc:153]   StreamExecutor device (3): TPU, 2a886c8
# I0000 00:00:1719797097.509370    6030 service.cc:153]   StreamExecutor device (4): TPU, 2a886c8
# I0000 00:00:1719797097.509373    6030 service.cc:153]   StreamExecutor device (5): TPU, 2a886c8
# I0000 00:00:1719797097.509375    6030 service.cc:153]   StreamExecutor device (6): TPU, 2a886c8
# I0000 00:00:1719797097.509378    6030 service.cc:153]   StreamExecutor device (7): TPU, 2a886c8
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)

# %%
# tf.keras.mixed_precision.set_global_policy("mixed_bfloat16") # For TPU
# tf.keras.mixed_precision.set_global_policy('mixed_float16') # For GPU

# %%
# Import standard dependencies
import random
import cv2
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.utils import shuffle
from tqdm import tqdm

import tensorflow as tf
# Import tensorflow dependencies - Functional API


# image preprocessing
from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator, load_img

# to build model
from keras.models import Model
from tensorflow.keras.layers import Rescaling, Input, Conv2D, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, GroupNormalization, DepthwiseConv2D, LayerNormalization, Concatenate
from tensorflow.keras.activations import softmax

# cost function / optimizer
from tensorflow.keras.optimizers import SGD, Adamax
from sklearn.metrics import confusion_matrix

# %%
SEED = 178
tf.random.set_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)
# tf.config.experimental.enable_op_determinism()

# %%
train_paths = []
test_paths = []
train_labels = []
test_labels = []

live_train = 0
live_test = 0
spoof_train = 0
spoof_test = 0


train_test = ['/kaggle/input/celeba-spoof-for-face-antispoofing/CelebA_Spoof_/CelebA_Spoof/Data/train', '/kaggle/input/celeba-spoof-for-face-antispoofing/CelebA_Spoof_/CelebA_Spoof/Data/test']
for i in range(2):
    for file in tqdm(os.listdir(train_test[i])):
        d = os.path.join(train_test[i], file)
        if os.path.isdir(d):
            for e in os.listdir(d):
                imgs_path = d + '/' + e + '/'
                for img_path in os.listdir(imgs_path):
                    if (img_path.endswith(".jpg") or img_path.endswith(".png")):
                        if(img_path=='004046.jpg'):
                            continue
                        full_img_path = imgs_path + img_path
                        if(i==0): #train
                            train_paths.append(full_img_path)
                            if e == 'live':
                                live_train = live_train + 1
                                train_labels.append(1)
                            elif e == 'spoof':
                                spoof_train = spoof_train + 1
                                train_labels.append(0)
                        else:
                            test_paths.append(full_img_path)
                            if e == 'live':
                                live_test = live_test + 1
                                test_labels.append(1)
                            elif e == 'spoof':
                                spoof_test = spoof_test + 1
                                test_labels.append(0)

print(len(train_paths),len(train_labels),len(test_paths),len(test_labels))
print(live_train, live_test, spoof_train, spoof_test)
# Out:
# 100%|██████████| 8192/8192 [04:07<00:00, 33.11it/s]
# 100%|██████████| 1004/1004 [00:26<00:00, 37.54it/s]
# 494404 494404 67170 67170
# 164484 19923 329920 47247

# %%
train_paths, train_labels = shuffle(train_paths, train_labels, random_state=SEED)

# %%
ds = tf.data.Dataset.from_tensor_slices((train_paths,train_labels)) #.shuffle(1000,178)
test_ds = tf.data.Dataset.from_tensor_slices((test_paths,test_labels))

for element in ds.take(1):
    print(element)
for element in test_ds.take(1):
    print(element)
# Out:
# (<tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/celeba-spoof-for-face-antispoofing/CelebA_Spoof_/CelebA_Spoof/Data/train/3833/live/173130.jpg'>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)
# (<tf.Tensor: shape=(), dtype=string, numpy=b'/kaggle/input/celeba-spoof-for-face-antispoofing/CelebA_Spoof_/CelebA_Spoof/Data/test/5550/live/526975.png'>, <tf.Tensor: shape=(), dtype=int32, numpy=1>)

# %%
def get_ratio_bbox_and_image(shape, bound_box_path):
    real_h, real_w, _ = shape
    area_image = real_h * real_w
    x1, y1, w1, h1 = get_area_bbox_indices(bound_box_path, real_w, real_h)
    area_bbox = w1*h1
    return area_bbox / area_image


def standard_width_height_scaling(real_w, real_h, bbox0, bbox1, bbox2, bbox3):
    x1 = int(int(bbox0)*(float(real_w) / 224)) 
    y1 = int(int(bbox1)*(float(real_h) / 224)) 
    w1 = int(int(bbox2)*(float(real_w) / 224)) 
    h1 = int(int(bbox3)*(float(real_h) / 224)) 
    return x1, y1, w1, h1


def get_area_bbox_indices(bound_box_path, real_w, real_h):
    bound_box_read = open(bound_box_path, "r")
    bound_box_indices = list()
    for i in bound_box_read:
        bound_box_indices.append(i)
    bbox = bound_box_indices[0].split()
    x1, y1, w1, h1 = standard_width_height_scaling(real_w, real_h, bbox[0], bbox[1], bbox[2], bbox[3])
    return x1, y1, w1, h1

def get_padding_bbox_indices(x1, y1, w1, h1, real_w, real_h, ratio_bbox_and_image):
    x1_padding = x1 - int((w1) * (1+ratio_bbox_and_image))
    y1_padding = y1 - int((h1) * (1+ratio_bbox_and_image))
    w1_padding = w1 + int((w1) * (1+ratio_bbox_and_image))
    h1_padding = h1 + int((h1) * (1+ratio_bbox_and_image))
    if x1_padding < 0: 
        x1_padding = 0
    if y1_padding < 0:
        y1_padding = 0
    if w1_padding > real_w:
        w1_padding = real_w
    if h1_padding > real_h:
        h1_padding = real_h
    return x1_padding, y1_padding, w1_padding, h1_padding
    
def read_crop_img_with_bbox(shape, bound_box_path):
    real_h, real_w, _ = shape
    x1, y1, w1, h1 = get_area_bbox_indices(bound_box_path, real_w, real_h)
    return x1, y1, w1, h1, real_w, real_h

# %%
def process_path_and_bbox(img_path, real_h, real_w, channels):
    img_path_str = img_path.numpy().decode('utf-8')
    bound_box_path = img_path_str[:-4] + '_BB.txt'
    shape = (real_h.numpy(), real_w.numpy(), channels.numpy())
    x1, y1, w1, h1, real_w, real_h = read_crop_img_with_bbox(shape, bound_box_path)
    ratio_bbox_and_image = get_ratio_bbox_and_image(shape, bound_box_path)
    x1_padding, y1_padding, w1_padding, h1_padding = get_padding_bbox_indices(
        x1, y1, w1, h1, real_w, real_h, ratio_bbox_and_image
    )
    return x1_padding, y1_padding, w1_padding, h1_padding

# %%
imgShape = [150, 150, 3]
imgShapeFreq = [150, 150, 1]
def preprocess(img_path, label):
    img = tf.io.read_file(img_path)
    img = tf.io.decode_image(img, channels=3)
    
    # Ensure that img has a known shape
    img = tf.ensure_shape(img, [None, None, 3])
    
    shape = tf.shape(img)
    real_h, real_w, channels = shape[0], shape[1], shape[2]

    x1_padding, y1_padding, w1_padding, h1_padding = tf.py_function(
        func=process_path_and_bbox,
        inp=[img_path, real_h, real_w, channels],
        Tout=[tf.int32, tf.int32, tf.int32, tf.int32]
    )
    
    # Very important to set the shape of py_function outputs
    # Ensure shapes are defined 
    x1_padding.set_shape([])
    y1_padding.set_shape([])
    w1_padding.set_shape([])
    h1_padding.set_shape([])

    img = img[y1_padding:y1_padding + h1_padding, x1_padding:x1_padding + w1_padding]

    img.set_shape([None, None, 3])
    img = tf.image.resize(img, size=imgShape[:2])
    gray_img = tf.image.rgb_to_grayscale(img)
    imgHSV = tf.image.rgb_to_hsv(img/255.0)*255.0
    
    # Perform Fourier Transform using TensorFlow functions
    f = tf.signal.fft2d(tf.cast(gray_img, tf.complex64))
    fshift = tf.signal.fftshift(f)
    magnitude_spectrum = tf.math.abs(fshift)
    
    # The range for magnitude_spectrum is [0, 255*height*width] and we want it to become [0, 255]
    magnitude_spectrum = magnitude_spectrum / (imgShape[0] * imgShape[1])
    
    # Convert magnitude_spectrum to the shape needed
    # magnitude_spectrum = tf.expand_dims(magnitude_spectrum, axis=-1)
    
    """
    # Fourier Transform
    f = np.fft.fft2(tf.image.rgb_to_grayscale(tf.cast(img,tf.uint8)).numpy())
    fshift = np.fft.fftshift(f)
    magnitude_spectrum = np.abs(fshift)
    magnitude_spectrum = tf.convert_to_tensor(magnitude_spectrum)
    # The minimum value for the magnitude_spectrum is 0 and the maximum is 255*height*width
    magnitude_spectrum = magnitude_spectrum/(255.0*imgShape[0]*imgShape[1]) - 1.0
    """
    return (imgHSV, magnitude_spectrum), label

# %%
examples_count = tf.data.experimental.cardinality(ds).numpy()
print(examples_count)
train_size = int(examples_count * 0.90)
train_ds = ds.take(train_size)
val_ds = ds.skip(train_size)
print(tf.data.experimental.cardinality(train_ds).numpy())
print(tf.data.experimental.cardinality(val_ds).numpy())
print(tf.data.experimental.cardinality(test_ds).numpy())

AUTOTUNE = tf.data.AUTOTUNE

# Set `num_parallel_calls` so multiple images are loaded/processed in parallel.
train_ds = train_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
val_ds = val_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
test_ds = test_ds.map(preprocess, num_parallel_calls=AUTOTUNE)
# Out:
# 494404
# 444963
# 49441
# 67170

# %%
plt.figure(figsize=(6, 6))
cnt = 0
for idx, ((image, magnitude_spectrum), label) in enumerate(train_ds.take(4)):
    ax = plt.subplot(2, 4, cnt + 1)
    ax.imshow(tf.cast(image,tf.int32))
    ax.set_title(f"Label: {label}")
    ax.axis('off')
    
    ax = plt.subplot(2, 4, cnt + 2)
    ax.imshow(magnitude_spectrum)
    ax.set_title(f"Label: {label}")
    ax.axis('off')
    cnt = cnt + 2
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnt = 0
for idx, ((image, magnitude_spectrum), label) in enumerate(val_ds.take(4)):
    ax = plt.subplot(2, 4, cnt + 1)
    ax.imshow(tf.cast(image,tf.int32))
    ax.set_title(f"Label: {label}")
    ax.axis('off')
    
    ax = plt.subplot(2, 4, cnt + 2)
    ax.imshow(magnitude_spectrum)
    ax.set_title(f"Label: {label}")
    ax.axis('off')
    cnt = cnt + 2
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(6, 6))
cnt = 0
for idx, ((image, magnitude_spectrum), label) in enumerate(test_ds.take(4)):
    ax = plt.subplot(2, 4, cnt + 1)
    ax.imshow(tf.cast(image,tf.int32))
    ax.set_title(f"Label: {label}")
    ax.axis('off')
    
    ax = plt.subplot(2, 4, cnt + 2)
    ax.imshow(magnitude_spectrum)
    ax.set_title(f"Label: {label}")
    ax.axis('off')
    cnt = cnt + 2
plt.tight_layout()
plt.show()

# %%
def random_horizontal_flip(img, label):
    img = tf.image.random_flip_left_right(img)
    return img, label
def random_vertical_flip(img, label):
    img = tf.image.random_flip_up_down(img)
    return img, label
def random_rotation(img, label):
    img = tf.image.rot90(img, k=1) #k=tf.random.uniform(shape=[], minval=0, maxval=4, dtype=tf.int32)
    return img, label
def random_hue(img, label):
    img = tf.image.random_hue(img, 0.1)
    return img, labelargmax

# %%
"""
To train a model with this dataset you will want the data:
  To be well shuffled.
  To be batched.
  Batches to be available as soon as possible.
"""
batch_size_per_replica = 32
batch_size = batch_size_per_replica * strategy.num_replicas_in_sync
def configure_for_performance(ds, shuffle=False, augment=False):
    if augment:
        ds=ds.map(random_horizontal_flip)\
             .map(random_vertical_flip)\
             .map(random_rotation)\
             .map(random_hue)
            
    if shuffle:
        ds=ds.shuffle(1000)
    ds = ds.cache()
    ds = ds.batch(batch_size, drop_remainder=False)
    ds = ds.prefetch(buffer_size=AUTOTUNE)
    return ds

# %%
train_ds = configure_for_performance(train_ds)
val_ds = configure_for_performance(val_ds)
test_ds = configure_for_performance(test_ds)

# %%
class TestMonitor(tf.keras.callbacks.Callback):
    def __init__(self, test_data, verbose=0):
        super(TestMonitor, self).__init__()
        self.test_data = test_data
        self.verbose = verbose
        self.best_acc = None
        self.best_weights = None

    def on_epoch_end(self, epoch, logs=None):
        loss, acc = self.model.evaluate(self.test_data, verbose=0)

        if self.best_acc is None or acc >= self.best_acc:
            self.best_acc = acc
            self.best_weights = self.model.get_weights()

            if self.verbose > 0:
                print(f" Test Accuracy Improved ({self.best_acc:.4f}) - Saving Weights")
        else:
            if self.verbose > 0:
                print(f" Test Accuracy ({acc:.4f}) did not improve.")

    def on_train_end(self, logs=None):
        if self.best_weights is not None:
            self.model.set_weights(self.best_weights)
            print("Loaded weights with best Test Accuracy")

# %%
def create_freq_stream(input_shape):
    inputs = Input(shape=input_shape)
    x = GroupNormalization(-1)(inputs)
    x = DepthwiseConv2D((5,5),(1,1))(x)
    x = MaxPooling2D((8, 8))(x)
    x = LayerNormalization()(inputs)
    x = MaxPooling2D((2, 2))(x)
    # x = tf.keras.layers.Flatten()(x)
    x = GlobalAveragePooling2D(name="avg_pool1")(x)
    model = Model(inputs, x)
    return model

# %%
def create_spatial_stream(input_shape):
    inputs = Input(shape=imgShape)
    xception = tf.keras.applications.EfficientNetB3(include_top=False, weights="imagenet", input_shape=imgShape)
    xception.trainable = True
    x = xception(inputs)
    x = GlobalAveragePooling2D(name="avg_pool2")(x)
    model = Model(inputs, x)
    return model

# %%
with strategy.scope():
    spatial_stream = create_spatial_stream(imgShape)
    freq_stream = create_freq_stream(imgShapeFreq)
    x = Concatenate()([spatial_stream.output, freq_stream.output])
    top_dropout_rate = .4
    x = Dropout(top_dropout_rate, name="top_dropout")(x)
    x = Dense(units=512, activation='relu')(x)
    output = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=[spatial_stream.input, freq_stream.input], outputs=output)
    model.compile(optimizer="adamax", loss='binary_crossentropy', metrics=['accuracy'])

# %%
print("Ready to train. Training is starting!\n")
callbacks = [TestMonitor(test_ds, verbose=1)]
hist = model.fit(train_ds, validation_data=val_ds, callbacks=callbacks, epochs=30,verbose=1)
# Out:
# Ready to train. Training is starting!
#
# Epoch 1/30
# 2024-07-01 01:49:30.601522: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node StatefulPartitionedCall.
# I0000 00:00:1719798574.353421    6767 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(85bb282b2c083d5c:0:0), session_name()
# I0000 00:00:1719798610.354236    6767 tpu_compile_op_common.cc:245] Compilation of 85bb282b2c083d5c:0:0 with session name  took 36.000737653s and succeeded
# I0000 00:00:1719798610.515259    6767 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(85bb282b2c083d5c:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_17082492941699858230", property.function_library_fingerprint = 3086384565774208460, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "32,150,150,3,;32,150,150,1,;32,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1719798610.515338    6767 tpu_compilation_cache_interface.cc:541] After adding entry for key 85bb282b2c083d5c:0:0 with session_name  cache is 5 entries (666344273 bytes),  marked for eviction 0 entries (0 bytes).
# 1738/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9646 - loss: 0.0883
# I0000 00:00:1719798891.635513    6791 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(6e382671422ec856:0:0), session_name()
# I0000 00:00:1719798925.018445    6791 tpu_compile_op_common.cc:245] Compilation of 6e382671422ec856:0:0 with session name  took 33.382844758s and succeeded
# I0000 00:00:1719798925.211731    6791 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(6e382671422ec856:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_17082492941699858230", property.function_library_fingerprint = 3086384565774208460, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "5,150,150,3,;5,150,150,1,;5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1719798925.211814    6791 tpu_compilation_cache_interface.cc:541] After adding entry for key 6e382671422ec856:0:0 with session_name  cache is 6 entries (861185307 bytes),  marked for eviction 0 entries (0 bytes).
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.9646 - loss: 0.0883
# 2024-07-01 01:55:36.384147: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node AssignVariableOp.
# I0000 00:00:1719798937.539668    6826 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(d8767196c921d35b:0:0), session_name()
# I0000 00:00:1719798955.699446    6826 tpu_compile_op_common.cc:245] Compilation of d8767196c921d35b:0:0 with session name  took 18.159712268s and succeeded
# I0000 00:00:1719798955.723194    6826 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(d8767196c921d35b:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_18111805508343121852", property.function_library_fingerprint = 3714991329569004511, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "32,150,150,3,;32,150,150,1,;32,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1719798955.723229    6826 tpu_compilation_cache_interface.cc:541] After adding entry for key d8767196c921d35b:0:0 with session_name  cache is 7 entries (897091291 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1719798966.023741    6771 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(360077d0e88128f:0:0), session_name()
# I0000 00:00:1719798972.327790    6771 tpu_compile_op_common.cc:245] Compilation of 360077d0e88128f:0:0 with session name  took 6.304001121s and succeeded
# I0000 00:00:1719798972.348194    6771 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(360077d0e88128f:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_18111805508343121852", property.function_library_fingerprint = 3714991329569004511, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "5,150,150,3,;5,150,150,1,;5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1719798972.348239    6771 tpu_compilation_cache_interface.cc:541] After adding entry for key 360077d0e88128f:0:0 with session_name  cache is 8 entries (931283969 bytes),  marked for eviction 0 entries (0 bytes).
# I0000 00:00:1719799087.809442    6808 tpu_compilation_cache_interface.cc:441] TPU host compilation cache miss: cache_key(f948cd31ecae2518:0:0), session_name()
# I0000 00:00:1719799094.185404    6808 tpu_compile_op_common.cc:245] Compilation of f948cd31ecae2518:0:0 with session name  took 6.375895373s and succeeded
# I0000 00:00:1719799094.205767    6808 tpu_compilation_cache_interface.cc:475] TPU host compilation cache: compilation complete for cache_key(f948cd31ecae2518:0:0), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_iterator_18111805508343121852", property.function_library_fingerprint = 3714991329569004511, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "13,150,150,3,;13,150,150,1,;13,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1719799094.205807    6808 tpu_compilation_cache_interface.cc:541] After adding entry for key f948cd31ecae2518:0:0 with session_name  cache is 9 entries (963965519 bytes),  marked for eviction 0 entries (0 bytes).
#  Test Accuracy Improved (0.9224) - Saving Weights
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 653s 279ms/step - accuracy: 0.9646 - loss: 0.0883 - val_accuracy: 0.9939 - val_loss: 0.0153
# Epoch 2/30
# 1473/1739 ━━━━━━━━━━━━━━━━━━━━ 44s 166ms/step - accuracy: 0.9966 - loss: 0.0104 Test Accuracy (0.8891) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 316s 181ms/step - accuracy: 0.9966 - loss: 0.0103 - val_accuracy: 0.9976 - val_loss: 0.0076
# Epoch 3/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9989 - loss: 0.0030 Test Accuracy (0.8975) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 315s 181ms/step - accuracy: 0.9989 - loss: 0.0030 - val_accuracy: 0.9966 - val_loss: 0.0098
# Epoch 4/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9990 - loss: 0.0033 Test Accuracy (0.9007) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 315s 181ms/step - accuracy: 0.9990 - loss: 0.0033 - val_accuracy: 0.9963 - val_loss: 0.0144
# Epoch 5/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9990 - loss: 0.0028 Test Accuracy (0.9031) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 313s 179ms/step - accuracy: 0.9990 - loss: 0.0028 - val_accuracy: 0.9984 - val_loss: 0.0054
# Epoch 6/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9993 - loss: 0.0021 Test Accuracy (0.9129) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 315s 181ms/step - accuracy: 0.9993 - loss: 0.0021 - val_accuracy: 0.9971 - val_loss: 0.0156
# Epoch 7/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - accuracy: 0.9991 - loss: 0.0022 Test Accuracy (0.9002) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 318s 182ms/step - accuracy: 0.9991 - loss: 0.0022 - val_accuracy: 0.9981 - val_loss: 0.0091
# Epoch 8/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9992 - loss: 0.0022 Test Accuracy Improved (0.9278) - Saving Weights
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 315s 181ms/step - accuracy: 0.9992 - loss: 0.0022 - val_accuracy: 0.9979 - val_loss: 0.0108
# Epoch 9/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9993 - loss: 0.0018 Test Accuracy (0.9008) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 309s 177ms/step - accuracy: 0.9993 - loss: 0.0018 - val_accuracy: 0.9976 - val_loss: 0.0107
# Epoch 10/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9995 - loss: 0.0011 Test Accuracy (0.9039) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 315s 181ms/step - accuracy: 0.9995 - loss: 0.0011 - val_accuracy: 0.9981 - val_loss: 0.0082
# Epoch 11/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9995 - loss: 0.0013 Test Accuracy (0.8773) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 313s 180ms/step - accuracy: 0.9995 - loss: 0.0013 - val_accuracy: 0.9971 - val_loss: 0.0116
# Epoch 12/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9996 - loss: 0.0029 Test Accuracy (0.8929) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 308s 177ms/step - accuracy: 0.9996 - loss: 0.0029 - val_accuracy: 0.9979 - val_loss: 0.0102
# Epoch 13/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9995 - loss: 0.0014 Test Accuracy (0.8654) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 313s 179ms/step - accuracy: 0.9995 - loss: 0.0014 - val_accuracy: 0.9981 - val_loss: 0.0088
# Epoch 14/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9996 - loss: 0.0012 Test Accuracy (0.8840) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 312s 179ms/step - accuracy: 0.9996 - loss: 0.0012 - val_accuracy: 0.9977 - val_loss: 0.0154
# Epoch 15/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9996 - loss: 0.0015 Test Accuracy (0.8989) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 313s 180ms/step - accuracy: 0.9996 - loss: 0.0015 - val_accuracy: 0.9984 - val_loss: 0.0114
# Epoch 16/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9997 - loss: 8.6759e-04 Test Accuracy (0.9127) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 313s 180ms/step - accuracy: 0.9997 - loss: 8.6769e-04 - val_accuracy: 0.9985 - val_loss: 0.0081
# Epoch 17/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9995 - loss: 9.4271e-04 Test Accuracy (0.8903) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 311s 178ms/step - accuracy: 0.9995 - loss: 9.4248e-04 - val_accuracy: 0.9984 - val_loss: 0.0102
# Epoch 18/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.9996 - loss: 0.0014 Test Accuracy (0.8716) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 307s 176ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9977 - val_loss: 0.0115
# Epoch 19/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9999 - loss: 2.9959e-04 Test Accuracy (0.8566) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 310s 178ms/step - accuracy: 0.9999 - loss: 2.9982e-04 - val_accuracy: 0.9979 - val_loss: 0.0144
# Epoch 20/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9995 - loss: 0.0012 Test Accuracy (0.8646) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 309s 177ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9984 - val_loss: 0.0079
# Epoch 21/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9999 - loss: 5.2477e-04 Test Accuracy (0.8678) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 312s 179ms/step - accuracy: 0.9999 - loss: 5.2478e-04 - val_accuracy: 0.9985 - val_loss: 0.0102
# Epoch 22/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.9997 - loss: 9.8145e-04 Test Accuracy (0.9059) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 314s 180ms/step - accuracy: 0.9997 - loss: 9.8129e-04 - val_accuracy: 0.9977 - val_loss: 0.0179
# Epoch 23/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - accuracy: 0.9998 - loss: 5.2295e-04 Test Accuracy (0.8723) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 308s 177ms/step - accuracy: 0.9998 - loss: 5.2285e-04 - val_accuracy: 0.9977 - val_loss: 0.0125
# Epoch 24/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9999 - loss: 5.1226e-04 Test Accuracy (0.8723) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 310s 178ms/step - accuracy: 0.9999 - loss: 5.1235e-04 - val_accuracy: 0.9977 - val_loss: 0.0148
# Epoch 25/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9997 - loss: 9.2106e-04 Test Accuracy (0.8739) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 311s 178ms/step - accuracy: 0.9997 - loss: 9.2081e-04 - val_accuracy: 0.9971 - val_loss: 0.0169
# Epoch 26/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9997 - loss: 0.0012 Test Accuracy (0.9044) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 310s 178ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9974 - val_loss: 0.0154
# Epoch 27/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 1.0000 - loss: 5.1375e-05 Test Accuracy (0.8915) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 307s 176ms/step - accuracy: 1.0000 - loss: 5.1454e-05 - val_accuracy: 0.9976 - val_loss: 0.0158
# Epoch 28/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.9996 - loss: 0.0014 Test Accuracy (0.8796) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 311s 179ms/step - accuracy: 0.9996 - loss: 0.0014 - val_accuracy: 0.9977 - val_loss: 0.0085
# Epoch 29/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9999 - loss: 2.8251e-04 Test Accuracy (0.8596) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 311s 178ms/step - accuracy: 0.9999 - loss: 2.8262e-04 - val_accuracy: 0.9981 - val_loss: 0.0127
# Epoch 30/30
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.9999 - loss: 7.2407e-04 Test Accuracy (0.8666) did not improve.
# 1739/1739 ━━━━━━━━━━━━━━━━━━━━ 309s 177ms/step - accuracy: 0.9999 - loss: 7.2408e-04 - val_accuracy: 0.9981 - val_loss: 0.0111
# Loaded weights with best Test Accuracy

# %%
eps = range(len(hist.history["loss"]))
plt.figure(figsize=(10, 6))
plt.plot(eps, hist.history["loss"])
plt.plot(eps, hist.history["val_loss"])
plt.legend(["loss", "val_loss"])

eps = range(len(hist.history["accuracy"]))
plt.figure(figsize=(10, 6))
plt.plot(eps, hist.history["accuracy"])
plt.plot(eps, hist.history["val_accuracy"])
plt.legend(["accuracy", "val_accuracy"])

# %%
loss, accuracy = model.evaluate(test_ds)
# Out:
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 16s 59ms/step - accuracy: 0.9133 - loss: 0.5397

# %%
print(f"Test accuracy: {accuracy*100:.2f}%")
# Out:
# Test accuracy: 92.78%

# %%
true_labels = []
for img_batch, labels_batch in test_ds:
    true_labels.extend(labels_batch.numpy())

# %%
def plot_confusion_matrix(true_labels,predictions,modelname):
    cm = confusion_matrix(true_labels, predictions)
    sns.heatmap(cm, annot=True)
    plt.title(f"Confusion Matrix for {modelname}")
    plt.show()

# %%
# squeeze removes dimensions of size 1 from the shape of a tensor.
predicted_labels_exception = np.array([1 if x >= 0.5 else 0 for x in tf.squeeze(model.predict(test_ds))]) 
print(f"Test accuracy: {accuracy*100:.2f}%")
plot_confusion_matrix(true_labels, predicted_labels_exception,"xception")
# Out:
# 263/263 ━━━━━━━━━━━━━━━━━━━━ 51s 191ms/step
# Test accuracy: 92.78%
